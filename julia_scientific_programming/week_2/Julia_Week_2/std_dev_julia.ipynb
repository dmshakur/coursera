# %% [markdown]
# Creating a function in Julia for

# %%
using Plots

# %%
function pop_std_dev(arr::Array{Int64})
    n = length(arr)
    μ = sum(arr) / n
    Σ = 0
    for num in arr
        Σ += (num - μ)^2
    end
    √Σ/n
end
# Out:
# pop_std_dev (generic function with 1 method)

# %% [markdown]
# A function that returns the standard deviation of a population given an array

# %%
arr = [1, 2, 3, 2, 4, 5, 3, 4, 3]
# Out:
# 9-element Array{Int64,1}:
#  1
#  2
#  3
#  2
#  4
#  5
#  3
#  4
#  3

# %%
pop_std_dev(a)
# Out:
# UndefVarError: a not defined
#
# Stacktrace:
#  [1] top-level scope at In[4]:1

# %%
new_arr = arr .+ 1
# Out:
# 9-element Array{Int64,1}:
#  2
#  3
#  4
#  3
#  5
#  6
#  4
#  5
#  4

# %%
for i = -10:10
    new_arr .+ i
    display(plot(new_arr))
end
