# %%
import os, wget, json, requests
import numpy as np
import matplotlib.pyplot as plt
from watson_machine_learning_client import WatsonMachineLearningAPIClient
# Out:
# ----------------------------------------------------------------------
# ImportError                          Traceback (most recent call last)
# <ipython-input-1-4ed0d803b78f> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from watson_machine_learning_client import WatsonMachineLearningAPIClient
#
# ~/source_files/anaconda3/lib/python3.7/site-packages/watson_machine_learning_client/__init__.py in <module>
#      15     pass
#      16 from .utils import version
# ---> 17 from .client import WatsonMachineLearningAPIClient
#      18
#      19 from .utils import is_python_2
#
# ~/source_files/anaconda3/lib/python3.7/site-packages/watson_machine_learning_client/client.py in <module>
#      12 from watson_machine_learning_client.learning_system import LearningSystem
#      13 from watson_machine_learning_client.experiments import Experiments
# ---> 14 from watson_machine_learning_client.repository import Repository
# ...
